# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns
import altair as alt
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('../data/training.csv')

# %%
train.head()
# Out:
#    YEAR FORECAST MADE  QUARTER  YEAR BEING FORECAST   INDICATOR  \
# 0                1968        4                 1968  NominalGNP
# 1                1968        4                 1968  NominalGNP
# 2                1968        4                 1968  NominalGNP
# 3                1968        4                 1968  NominalGNP
# 4                1968        4                 1968  NominalGNP
#
#    FORECASTER ID  INDUSTRY Year.ID.ForecastYear.Quarter  \
# 0             32       NaN               1968-32-1968-4
# 1             77       NaN               1968-77-1968-4
# 2             37       NaN               1968-37-1968-4
# 3             53       NaN               1968-53-1968-4
# 4             66       NaN               1968-66-1968-4
#
#   Indicator.Year.ID.ForecastYear.Quarter  BIN 1  BIN 2  ...  bin_value_sum  \
# 0              NominalGNP-1968-32-1968-4    0.0    0.0  ...          100.0
# 1              NominalGNP-1968-77-1968-4   15.0    6.0  ...          100.0
# 2              NominalGNP-1968-37-1968-4    0.0    1.0  ...          100.0
# 3              NominalGNP-1968-53-1968-4    5.0   10.0  ...          100.0
# 4              NominalGNP-1968-66-1968-4    0.0    0.0  ...          100.0
#
#    TDIST   actual  ACTUAL_BIN   MAX  NUM_OF_MAX  ACTUAL_CONF  HIT  \
# 0    0.0  9.40449         2.0  0.50         1.0         0.00  0.0
# 1    0.0  9.40449         2.0  0.15         1.0         0.06  0.0
# 2    0.0  9.40449         2.0  0.25         1.0         0.01  0.0
# 3    0.0  9.40449         2.0  0.40         1.0         0.10  0.0
# 4    0.0  9.40449         2.0  0.95         1.0         0.00  0.0
#
#    pred_average  pred_var
# 0          6.65    0.6275
# 1          5.41   13.2419
# 2          2.89    4.3579
# 3          7.50    2.0000
# 4          7.51    0.0499
#
# [5 rows x 64 columns]

# %%
train.shape
# Out:
# (16217, 64)

# %%
train.columns
# Out:
# Index(['YEAR FORECAST MADE', 'QUARTER', 'YEAR BEING FORECAST', 'INDICATOR',
#        'FORECASTER ID', 'INDUSTRY', 'Year.ID.ForecastYear.Quarter',
#        'Indicator.Year.ID.ForecastYear.Quarter', 'BIN 1', 'BIN 2', 'BIN 3',
#        'BIN 4', 'BIN 5', 'BIN 6', 'BIN 7', 'BIN 8', 'BIN 9', 'BIN 10',
#        'BIN 11', 'BIN 12', 'BIN 13', 'BIN 14', 'BIN 15', 'BIN 1 prob',
#        'BIN 2 prob', 'BIN 3 prob', 'BIN 4 prob', 'BIN 5 prob', 'BIN 6 prob',
#        'BIN 7 prob', 'BIN 8 prob', 'BIN 9 prob', 'BIN 10 prob', 'BIN 11 prob',
#        'BIN 12 prob', 'BIN 13 prob', 'BIN 14 prob', 'BIN 15 prob',
#        'BIN 1 midpoint', 'BIN 2 midpoint', 'BIN 3 midpoint', 'BIN 4 midpoint',
#        'BIN 5 midpoint', 'BIN 6 midpoint', 'BIN 7 midpoint', 'BIN 8 midpoint',
#        'BIN 9 midpoint', 'BIN 10 midpoint', 'BIN 11 midpoint',
#        'BIN 12 midpoint', 'BIN 13 midpoint', 'BIN 14 midpoint',
#        'BIN 15 midpoint', 'nbin', 'bin_value_sum', 'TDIST', 'actual',
#        'ACTUAL_BIN', 'MAX', 'NUM_OF_MAX', 'ACTUAL_CONF', 'HIT', 'pred_average',
#        'pred_var'],
#       dtype='object')

# %% [markdown]
# EDA: check Nans for industry,pred_average, bins

# %%
train.isnull

# %%
def plot_na(indicator):
    nas = train.groupby("INDICATOR").agg(lambda x: x.isnull().sum())
    f = plt.figure(figsize=(20, 10))
    ax=sns.barplot(x=nas.loc[indicator].index,y=nas.loc[indicator])
    plt.xticks(rotation=90);
    plt.title(f"NA Counts for {indicator}");
    return plt.show()
for indicator in train.INDICATOR.unique():
    plot_na(indicator)

# %%
f = plt.figure(figsize=(15, 5))
means = train.iloc[:,8:23].apply(np.mean).reset_index()
ax=sns.barplot(x="index",y=0,data=means)
plt.ylabel("Average Value")
plt.title("Average Value for Bins");

# %%
sns.scatterplot(x="variable",y="value",data=nas,hue="INDICATOR")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-65da6652083c> in <module>
# ----> 1 sns.scatterplot(x="variable",y="value",data=nas,hue="INDICATOR")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     799
#     800     variables = _ScatterPlotter.get_semantics(locals())
# --> 801     p = _ScatterPlotter(
#     802         data=data, variables=variables,
#     803         x_bins=x_bins, y_bins=y_bins,
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `variable` for parameter `x`

# %%
train.groupby(["YEAR FORECAST MADE","INDICATOR"]).mean()
# Out:
#                                   QUARTER  YEAR BEING FORECAST  FORECASTER ID  \
# YEAR FORECAST MADE INDICATOR
# 1968               NominalGNP    4.000000               1968.0      44.977273
# 1969               NominalGNP    2.571429               1969.0      96.337662
# 1970               NominalGNP    2.866667               1970.0      79.693333
# 1971               NominalGNP    2.677852               1971.0      79.684564
# 1972               NominalGNP    2.481481               1972.0      77.096296
# ...                                   ...                  ...            ...
# 2018               Unemployment  2.506849               2019.5     521.523973
# 2019               Core CPI      1.512821               2019.5     528.897436
#                    Core PCE      1.512821               2019.5     530.846154
#                    RealGDP       1.512821               2020.5     520.192308
#                    Unemployment  1.512821               2020.5     525.141026
#
#                                  INDUSTRY      BIN 1      BIN 2      BIN 3  \
# YEAR FORECAST MADE INDICATOR
# 1968               NominalGNP         NaN   0.790698   1.767442   5.930233
# 1969               NominalGNP         NaN   0.810606   2.704545   7.651515
# 1970               NominalGNP         NaN   0.637037   1.829630   4.844444
# 1971               NominalGNP         NaN   2.440000  13.536000  23.048000
# 1972               NominalGNP         NaN  12.702290  41.061069  25.893130
# ...                                   ...        ...        ...        ...
# 2018               Unemployment  1.660959   0.009792   0.030729   0.041563
# 2019               Core CPI      1.679487   0.601450   1.077839   4.760521
#                    Core PCE      1.692308   0.511724   0.656794   2.700476
#                    RealGDP       1.717949   0.062881   0.331759   1.679413
#                    Unemployment  1.692308   0.019425   0.080588   0.133137
#
#                                      BIN 4      BIN 5      BIN 6  ...  \
# YEAR FORECAST MADE INDICATOR                                      ...
# 1968               NominalGNP    24.418605  27.790698  20.953488  ...
# 1969               NominalGNP    24.681818  22.712121  16.462121  ...
# 1970               NominalGNP    11.044444  17.051852  31.140741  ...
# 1971               NominalGNP    33.936000  14.792000   4.264000  ...
# 1972               NominalGNP    10.099237   5.854962   2.778626  ...
# ...                                    ...        ...        ...  ...
# 2018               Unemployment   0.141771   0.508854   1.210938  ...
# 2019               Core CPI      16.465850  45.347442  23.154694  ...
#                    Core PCE      12.725576  35.429803  33.200459  ...
#                    RealGDP       11.010339  40.447477  26.484317  ...
#                    Unemployment   0.460490   0.969314   1.944545  ...
#
#                                  bin_value_sum     TDIST    actual  \
# YEAR FORECAST MADE INDICATOR
# 1968               NominalGNP       100.000000  0.000000  9.404490
# 1969               NominalGNP       100.007576  0.357143  8.133090
# 1970               NominalGNP       100.000000  0.283333  5.467600
# 1971               NominalGNP       100.024000  0.330537  8.589440
# 1972               NominalGNP       100.038168  0.379630  9.827870
# ...                                        ...       ...       ...
# 2018               Unemployment     100.000000  1.873288  3.891667
# 2019               Core CPI          99.999998  1.121795       NaN
#                    Core PCE         100.000000  1.121795       NaN
#                    RealGDP          100.000004  2.121795       NaN
#                    Unemployment     100.000000  2.121795       NaN
#
#                                  ACTUAL_BIN       MAX  NUM_OF_MAX  \
# YEAR FORECAST MADE INDICATOR
# 1968               NominalGNP           2.0  0.483721    1.093023
# 1969               NominalGNP           3.0  0.488409    1.098485
# 1970               NominalGNP           6.0  0.489481    1.074074
# 1971               NominalGNP           3.0  0.537520    1.168000
# 1972               NominalGNP           2.0  0.569008    1.091603
# ...                                     ...       ...         ...
# 2018               Unemployment        10.0  0.608017    1.156250
# 2019               Core CPI             NaN  0.478358    1.196970
#                    Core PCE             NaN  0.463722    1.111111
#                    RealGDP              NaN  0.466943    1.099099
#                    Unemployment         NaN  0.584824    1.058824
#
#                                  ACTUAL_CONF       HIT  pred_average  pred_var
# YEAR FORECAST MADE INDICATOR
# 1968               NominalGNP       0.017674  0.000000      6.160930  1.782488
# 1969               NominalGNP       0.076515  0.030303      6.002955  1.517930
# 1970               NominalGNP       0.311407  0.425926      5.417185  1.481487
# 1971               NominalGNP       0.230480  0.194667      7.538881  0.797673
# 1972               NominalGNP       0.410611  0.595420      8.784050  0.716945
# ...                                      ...       ...           ...       ...
# 2018               Unemployment     0.610656  0.666667      4.095607  0.371148
# 2019               Core CPI              NaN       NaN      2.188734  0.270504
#                    Core PCE              NaN       NaN      2.027622  0.225065
#                    RealGDP               NaN       NaN      1.897140  1.137611
#                    Unemployment          NaN       NaN      4.206245  0.437900
#
# [90 rows x 60 columns]

# %%
by_year = train.groupby(["YEAR FORECAST MADE","INDICATOR"]).mean()
f = plt.figure(figsize=(20, 15))
sns.lineplot(x="YEAR FORECAST MADE", y= "pred_average",data=by_year,hue="INDICATOR",palette="Blues")
sns.lineplot(x="YEAR FORECAST MADE", y= "actual",data=by_year,hue="INDICATOR",palette = "Reds")
plt.ylabel("Outcome Value")
plt.title("Historical Outcome Prediction vs Actual");

# %% [markdown]
# # MSE of 1.4068

# %%
by indicator do this

# %%
def mse(actual,prediction):
    return np.mean((actual-prediction)**2)
mse(by_year["actual"],by_year["pred_average"])
# Out:
# 1.4068750792104312

# %% [markdown]
# ## Unemployment Regression

# %%
unemp = train[train['INDICATOR'] == "Unemployment"] #only look at unemployment for now

# %%
unemp.head()
# Out:
#       YEAR FORECAST MADE  QUARTER  YEAR BEING FORECAST     INDICATOR  \
# 6155                2009        2                 2009  Unemployment
# 6156                2009        2                 2009  Unemployment
# 6157                2009        2                 2009  Unemployment
# 6158                2009        2                 2009  Unemployment
# 6159                2009        2                 2009  Unemployment
#
#       FORECASTER ID  INDUSTRY Year.ID.ForecastYear.Quarter  \
# 6155            527       2.0              2009-527-2009-2
# 6156            540       2.0              2009-540-2009-2
# 6157            549       1.0              2009-549-2009-2
# 6158            484       2.0              2009-484-2009-2
# 6159            553       2.0              2009-553-2009-2
#
#      Indicator.Year.ID.ForecastYear.Quarter  BIN 1  BIN 2  ...  bin_value_sum  \
# 6155           Unemployment-2009-527-2009-2    0.0    0.0  ...          100.0
# 6156           Unemployment-2009-540-2009-2    0.0    0.0  ...          100.0
# 6157           Unemployment-2009-549-2009-2    0.0    0.0  ...          100.0
# 6158           Unemployment-2009-484-2009-2    3.0   12.0  ...          100.0
# 6159           Unemployment-2009-553-2009-2    0.0   10.0  ...          100.0
#
#       TDIST    actual  ACTUAL_BIN   MAX  NUM_OF_MAX  ACTUAL_CONF  HIT  \
# 6155    0.5  9.283333         4.0  0.60         1.0         0.60  1.0
# 6156    0.5  9.283333         4.0  0.40         2.0         0.40  0.5
# 6157    0.5  9.283333         4.0  0.55         1.0         0.55  1.0
# 6158    0.5  9.283333         4.0  0.27         1.0         0.27  1.0
# 6159    0.5  9.283333         4.0  0.45         1.0         0.40  0.0
#
#       pred_average  pred_var
# 6155        9.4500  0.060000
# 6156        8.8500  0.140000
# 6157        9.4750  0.061875
# 6158        9.2725  0.656369
# 6159        9.5750  0.175625
#
# [5 rows x 64 columns]

# %%
unemp['MAX'].value_counts() #their highest confidence in their prediction for unemployment rate
# Out:
# 0.5000    393
# 0.4000    286
# 0.6000    225
# 0.3500    154
# 0.4500    146
#          ...
# 0.2827      1
# 0.4680      1
# 0.4634      1
# 0.2200      1
# 0.9992      1
# Name: MAX, Length: 202, dtype: int64

# %%
unemp['HIT'].value_counts() #how many times they were accurate
# Out:
# 0.000000    1271
# 1.000000     713
# 0.500000     143
# 0.333333       9
# 0.250000       2
# 0.200000       1
# Name: HIT, dtype: int64

# %%
np.random.seed(0)
unemp_rand = unemp.sample(frac = 1)
#80/20 split
train = unemp_rand[:2704]
val = unemp_rand[2704:]

#filling na with 0 bc they replaced 0s with na in the original R code but we should definitely look into this more
train = train.fillna(0)
val = val.fillna(0)

X_train, Y_train = train[["FORECASTER ID", "INDUSTRY", "MAX", "pred_average", "pred_var", "HIT"]], train[["actual"]]
X_val, Y_val = val[["FORECASTER ID", "INDUSTRY", "MAX", "pred_average", "pred_var", "HIT"]], val[["actual"]]

# %%
lr = LinearRegression()
fitted = lr.fit(X_train, Y_train)
pred = fitted.predict(X_val)
pred = pred.flatten()

# %%
diffs = np.subtract(np.array(Y_val['actual'].tolist()), pred)
print("Differences in actual unemployment rate vs. model prediction")
print("Mean: " + str(np.mean(diffs)))
print("Median: " + str(np.median(diffs)))
print("Max: " + str(max(diffs)))
print("Min: " + str(min(diffs)))
# Out:
# Differences in actual unemployment rate vs. model prediction
# Mean: -0.11313845729614412
# Median: -0.04941656910178516
# Max: 5.980928386245965
# Min: -4.924484858853711

# %%
plt.hist(diffs)
plt.title("Actual Unemployment Rate minus Model Prediction")
plt.show()

# %%
actual_diffs = np.subtract(np.array(Y_val['actual'].tolist()), np.array(X_val['pred_average'].tolist()))
print("Differences in actual unemployment rate vs. forecaster average prediction")
print("Mean: " + str(np.mean(actual_diffs)))
print("Median: " + str(np.median(actual_diffs)))
print("Max: " + str(max(actual_diffs)))
print("Min: " + str(min(actual_diffs)))
# Out:
# Differences in actual unemployment rate vs. forecaster average prediction
# Mean: 0.08545953981755335
# Median: -0.375
# Max: 9.60833333333333
# Min: -6.0753

# %%
plt.hist(actual_diffs)
plt.title("Actual Unemployment Rate minus Forecaster Average Prediction")
plt.show()
