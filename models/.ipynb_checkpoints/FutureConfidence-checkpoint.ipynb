# %%
import pandas as pd
import numpy as np

data = pd.read_csv("../data/CleanData/fullData.csv")#,index_col=0)

# %%
datagrouped = data.groupby(["FORECASTER ID", "INDICATOR"]).agg({"ACTUAL_CONF": np.mean})

# %% [markdown]
# ## First Version - Gets average confidence for forecaster by Indicator

# %%
datagrouped = datagrouped.reset_index()
datagrouped
# Out:
#      level_0  index  FORECASTER ID     INDICATOR  ACTUAL_CONF
# 0          0      0             20      Core CPI     0.107143
# 1          1      1             20      Core PCE     0.150000
# 2          2      2             20       RealGDP     0.264344
# 3          3      3             20  Unemployment     0.262500
# 4          4      4             30       RealGDP     0.267857
# 5          5      5             35       RealGDP     0.212500
# 6          6      6             40       RealGDP     0.225000
# 7          7      7             60       RealGDP     0.290714
# 8          8      8             62       RealGDP     0.196250
# 9          9      9             65      Core CPI          NaN
# 10        10     10             65      Core PCE          NaN
# 11        11     11             65       RealGDP     0.286289
# 12        12     12             84      Core CPI     0.175000
# 13        13     13             84      Core PCE          NaN
# 14        14     14             84       RealGDP     0.259374
# 15        15     15             84  Unemployment     0.633333
# 16        16     16             94       RealGDP     0.171186
# 17        17     17             99      Core CPI     0.170000
# 18        18     18             99      Core PCE     0.151000
# 19        19     19             99       RealGDP     0.245556
# 20        20     20             99  Unemployment     0.132500
# 21        21     21            404       RealGDP     0.172115
# 22        22     22            405      Core CPI          NaN
# 23        23     23            405      Core PCE          NaN
# 24        24     24            405       RealGDP     0.275472
# 25        25     25            406       RealGDP     0.216667
# 26        26     26            407      Core CPI     0.195192
# 27        27     27            407      Core PCE     0.253125
# 28        28     28            407       RealGDP     0.383122
# 29        29     29            407  Unemployment     0.321184
# ..       ...    ...            ...           ...          ...
# 424      424    424            584       RealGDP     0.209227
# 425      425    425            584  Unemployment     0.392387
# 426      426    426            585      Core CPI     0.395000
# 427      427    427            585      Core PCE     0.355000
# 428      428    428            585       RealGDP     0.240000
# 429      429    429            585  Unemployment     0.390909
# 430      430    430            586      Core CPI     0.337000
# 431      431    431            586      Core PCE     0.326807
# 432      432    432            586       RealGDP     0.203355
# 433      433    433            586  Unemployment     0.342864
# 434      434    434            587      Core CPI     0.325000
# 435      435    435            587      Core PCE     0.210000
# 436      436    436            587       RealGDP     0.131579
# 437      437    437            587  Unemployment     0.230000
# 438      438    438            588      Core CPI     0.415556
# 439      439    439            588      Core PCE     0.342000
# 440      440    440            588       RealGDP     0.153529
# 441      441    441            588  Unemployment     0.198000
# 442      442    442            589      Core CPI     0.300000
# 443      443    443            589      Core PCE     0.000000
# 444      444    444            589       RealGDP     0.000000
# 445      445    445            589  Unemployment     0.000000
# 446      446    446            590      Core CPI     0.600000
# 447      447    447            590      Core PCE     0.400000
# 448      448    448            590       RealGDP     0.050000
# 449      449    449            590  Unemployment     0.000000
# 450      450    450            591      Core CPI          NaN
# 451      451    451            591      Core PCE          NaN
# 452      452    452            591       RealGDP          NaN
# 453      453    453            591  Unemployment          NaN
#
# [454 rows x 5 columns]

# %% [markdown]
# ## Second Version - Average Confidence Overall

# %%
datagrouped2 = data.groupby(["FORECASTER ID"]).agg({"ACTUAL_CONF": np.mean})

# %%
datagrouped2 = datagrouped2.reset_index()
datagrouped2
# Out:
#      FORECASTER ID  ACTUAL_CONF
# 0               20     0.239610
# 1               30     0.267857
# 2               35     0.212500
# 3               40     0.225000
# 4               60     0.290714
# 5               62     0.196250
# 6               65     0.286289
# 7               84     0.275214
# 8               94     0.171186
# 9               99     0.226667
# 10             404     0.172115
# 11             405     0.275472
# 12             406     0.216667
# 13             407     0.326356
# 14             408     0.270909
# 15             409     0.281250
# 16             410     0.150000
# 17             411     0.252572
# 18             412     0.326250
# 19             413     0.275000
# 20             414     0.176852
# 21             415     0.250000
# 22             416     0.305769
# 23             417     0.400000
# 24             418     0.280000
# 25             420     0.353199
# 26             421     0.288582
# 27             422     0.257202
# 28             423     0.184708
# 29             424     0.318102
# ..             ...          ...
# 148            557     0.334115
# 149            558     0.218605
# 150            559     0.278457
# 151            560     0.258826
# 152            561     0.278309
# 153            563     0.281578
# 154            564     0.313947
# 155            566     0.283333
# 156            568     0.276970
# 157            569     0.300000
# 158            570     0.274520
# 159            571     0.315125
# 160            572     0.320147
# 161            574     0.273403
# 162            575     0.271193
# 163            576     0.324173
# 164            577     0.288279
# 165            578     0.437339
# 166            579     0.352546
# 167            580     0.357576
# 168            581     0.347917
# 169            583     0.568462
# 170            584     0.306512
# 171            585     0.334783
# 172            586     0.292911
# 173            587     0.207143
# 174            588     0.255435
# 175            589     0.042857
# 176            590     0.191667
# 177            591          NaN
#
# [178 rows x 2 columns]

# %% [markdown]
# ## Testing Merge

# %%
relevant = data[data["YEAR FORECAST MADE"]>=1992][["YEAR FORECAST MADE",'YEAR BEING FORECAST', 'FORECASTER ID', 'INDICATOR', 'actual', 'MAX', 'pred_average', 'pred_var', 'banana', 'beef', 'bread', 'chicken',
        'eggs', 'electricity', 'flour', 'iceCream',
       'unleadedGasoline']]

# %%
predict_set = relevant[relevant["YEAR BEING FORECAST"]>2021]

# %%
predict_set.head()
# Out:
#        YEAR FORECAST MADE  YEAR BEING FORECAST  FORECASTER ID INDICATOR  \
# 26890                2019                 2022            411   RealGDP
# 26891                2019                 2022            421   RealGDP
# 26892                2019                 2022            422   RealGDP
# 26893                2019                 2022            423   RealGDP
# 26894                2019                 2022            424   RealGDP
#
#        actual   MAX  pred_average  pred_var  banana      beef     bread  \
# 26890     NaN   NaN           NaN       NaN   0.576  3.761333  1.272333
# 26891     NaN  0.35           1.8      1.01   0.576  3.761333  1.272333
# 26892     NaN   NaN           NaN       NaN   0.576  3.761333  1.272333
# 26893     NaN   NaN           NaN       NaN   0.576  3.761333  1.272333
# 26894     NaN   NaN           NaN       NaN   0.576  3.761333  1.272333
#
#         chicken      eggs  electricity     flour  iceCream  unleadedGasoline
# 26890  1.475667  1.551667     0.135333  0.442333  4.894667             2.402
# 26891  1.475667  1.551667     0.135333  0.442333  4.894667             2.402
# 26892  1.475667  1.551667     0.135333  0.442333  4.894667             2.402
# 26893  1.475667  1.551667     0.135333  0.442333  4.894667             2.402
# 26894  1.475667  1.551667     0.135333  0.442333  4.894667             2.402

# %%
# First Way Merge
predicted_conf = pd.merge(predict_set, datagrouped, how="left", left_on=["FORECASTER ID", "INDICATOR"], right_on=["FORECASTER ID", "INDICATOR"] )

# %%
predicted_conf.head()
# Out:
#    YEAR FORECAST MADE  YEAR BEING FORECAST  FORECASTER ID INDICATOR  actual  \
# 0                2019                 2022            411   RealGDP     NaN
# 1                2019                 2022            421   RealGDP     NaN
# 2                2019                 2022            422   RealGDP     NaN
# 3                2019                 2022            423   RealGDP     NaN
# 4                2019                 2022            424   RealGDP     NaN
#
#     MAX  pred_average  pred_var  banana      beef     bread   chicken  \
# 0   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
# 1  0.35           1.8      1.01   0.576  3.761333  1.272333  1.475667
# 2   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
# 3   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
# 4   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
#
#        eggs  electricity     flour  iceCream  unleadedGasoline  ACTUAL_CONF
# 0  1.551667     0.135333  0.442333  4.894667             2.402     0.220772
# 1  1.551667     0.135333  0.442333  4.894667             2.402     0.267844
# 2  1.551667     0.135333  0.442333  4.894667             2.402     0.231174
# 3  1.551667     0.135333  0.442333  4.894667             2.402     0.177899
# 4  1.551667     0.135333  0.442333  4.894667             2.402     0.297746

# %%
# Second Way Merge
predicted_conf2 = pd.merge(predict_set, datagrouped2, how="left", left_on=["FORECASTER ID"], right_on=["FORECASTER ID"] )

# %%
predicted_conf2.head()
# Out:
#    YEAR FORECAST MADE  YEAR BEING FORECAST  FORECASTER ID INDICATOR  actual  \
# 0                2019                 2022            411   RealGDP     NaN
# 1                2019                 2022            421   RealGDP     NaN
# 2                2019                 2022            422   RealGDP     NaN
# 3                2019                 2022            423   RealGDP     NaN
# 4                2019                 2022            424   RealGDP     NaN
#
#     MAX  pred_average  pred_var  banana      beef     bread   chicken  \
# 0   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
# 1  0.35           1.8      1.01   0.576  3.761333  1.272333  1.475667
# 2   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
# 3   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
# 4   NaN           NaN       NaN   0.576  3.761333  1.272333  1.475667
#
#        eggs  electricity     flour  iceCream  unleadedGasoline  ACTUAL_CONF
# 0  1.551667     0.135333  0.442333  4.894667             2.402     0.252572
# 1  1.551667     0.135333  0.442333  4.894667             2.402     0.288582
# 2  1.551667     0.135333  0.442333  4.894667             2.402     0.257202
# 3  1.551667     0.135333  0.442333  4.894667             2.402     0.184708
# 4  1.551667     0.135333  0.442333  4.894667             2.402     0.318102
