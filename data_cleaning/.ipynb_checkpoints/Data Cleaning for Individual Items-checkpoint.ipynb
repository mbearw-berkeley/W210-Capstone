# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
return_frame = pd.DataFrame([])

# %%
for filename in os.listdir("../data/RawData/BLS"):
    return_frame = pd.concat([return_frame,pd.read_csv("../data/RawData/BLS/"+filename).groupby("Year").agg(np.mean).rename(columns={"Value":filename.split("_")[0]})],axis=1)

# %%
def toQuarter(month):
    if month>=1 and month<=3:
        return 1
    elif month > 3 and month <=6:
        return 2
    elif month > 6 and month <= 9:
        return 3
    else: 
        return 4

# %%
def formatData(filename):
    data = pd.read_csv('../data/RawData/BLS/'+filename,usecols=["Year","Period","Value"])
    
    data.Period = data.Period.apply(lambda x: x[1:]).astype("int")
    data["Quarter"] = data.Period.apply(toQuarter)
    data = data.drop(columns=["Period"])
    data = data.groupby(["Year","Quarter"]).mean()
    return data

# %%
training = pd.read_csv("../data/TrainingData/fulldata.csv")

# %%
training
# Out:
#        YEAR FORECAST MADE  QUARTER  YEAR BEING FORECAST     INDICATOR  \
# 0                    1968        4                 1968    NominalGNP
# 1                    1968        4                 1968    NominalGNP
# 2                    1968        4                 1968    NominalGNP
# 3                    1968        4                 1968    NominalGNP
# 4                    1968        4                 1968    NominalGNP
# ...                   ...      ...                  ...           ...
# 36057                2021        2                 2024  Unemployment
# 36058                2021        2                 2024  Unemployment
# 36059                2021        2                 2024  Unemployment
# 36060                2021        2                 2024  Unemployment
# 36061                2021        2                 2024  Unemployment
#
#        FORECASTER ID  INDUSTRY Year.ID.ForecastYear.Quarter  \
# 0                  1       NaN                1968-1-1968-4
# 1                  2       NaN                1968-2-1968-4
# 2                  3       NaN                1968-3-1968-4
# 3                  4       NaN                1968-4-1968-4
# 4                  5       NaN                1968-5-1968-4
# ...              ...       ...                          ...
# 36057            586       2.0              2024-586-2021-2
# 36058            587       2.0              2024-587-2021-2
# 36059            588       1.0              2024-588-2021-2
# 36060            589       2.0              2024-589-2021-2
# 36061            590       1.0              2024-590-2021-2
#
#       Indicator.Year.ID.ForecastYear.Quarter  BIN 1  BIN 2  ...  \
# 0                   NominalGNP-1968-1-1968-4    0.0    0.0  ...
# 1                   NominalGNP-1968-2-1968-4    0.0    0.0  ...
# 2                   NominalGNP-1968-3-1968-4    0.0    0.0  ...
# 3                   NominalGNP-1968-4-1968-4    0.0    0.0  ...
# 4                   NominalGNP-1968-5-1968-4    3.0    4.0  ...
# ...                                      ...    ...    ...  ...
# 36057           Unemployment-2024-586-2021-2    NaN    NaN  ...
# 36058           Unemployment-2024-587-2021-2    0.0    0.0  ...
# 36059           Unemployment-2024-588-2021-2    NaN    NaN  ...
# 36060           Unemployment-2024-589-2021-2    0.0    0.0  ...
# 36061           Unemployment-2024-590-2021-2    NaN    NaN  ...
#
#        bin_value_sum  TDIST   actual  ACTUAL_BIN  MAX  NUM_OF_MAX  \
# 0              100.0    0.0  9.40449         2.0  0.6         1.0
# 1              100.0    0.0  9.40449         2.0  0.4         1.0
# 2              100.0    0.0  9.40449         2.0  0.5         1.0
# 3              100.0    0.0  9.40449         2.0  0.4         1.0
# 4              100.0    0.0  9.40449         2.0  0.3         1.0
# ...              ...    ...      ...         ...  ...         ...
# 36057            NaN    3.5      NaN         NaN  NaN         NaN
# 36058          100.0    3.5      NaN         NaN  0.5         1.0
# 36059            NaN    3.5      NaN         NaN  NaN         NaN
# 36060          100.0    3.5      NaN         NaN  0.9         1.0
# 36061            NaN    3.5      NaN         NaN  NaN         NaN
#
#        ACTUAL_CONF  HIT  pred_average  pred_var
# 0             0.00  0.0         6.000  0.450000
# 1             0.00  0.0         6.100  1.040000
# 2             0.00  0.0         6.800  0.410000
# 3             0.00  0.0         6.150  1.327500
# 4             0.04  0.0         4.650  7.227500
# ...            ...  ...           ...       ...
# 36057          NaN  NaN           NaN       NaN
# 36058          NaN  NaN         5.125  0.203125
# 36059          NaN  NaN           NaN       NaN
# 36060          NaN  NaN         5.175  0.050625
# 36061          NaN  NaN           NaN       NaN
#
# [36062 rows x 64 columns]

# %%
quarterFred= pd.read_csv("../data/CleanData/QuarterlyFred.csv",index_col=0)
quarterFred["DATE"] = quarterFred["DATE"].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
quarterFred["Year"] = quarterFred["DATE"].apply(lambda x:x.year)
quarterFred["Month"] = quarterFred["DATE"].apply(lambda y:y.month)
quarterFred["Quarter"] = quarterFred["Month"].apply(toQuarter)
quarterFred.drop(columns=["Month"],inplace=True)
quarterFred.head()
# Out:
#         DATE  GDPC1_PCH  GNP_PCH  GNPC96_PCH  CPILFESL  PCEPILFE  JHDUSRGDPBR  \
# 0 1947-04-01   -0.26669  1.19643    -0.23978       NaN       NaN          NaN
# 1 1947-07-01   -0.20650  1.47857    -0.20822       NaN       NaN          NaN
# 2 1947-10-01    1.56421  4.09427     1.58636       NaN       NaN          NaN
# 3 1948-01-01    1.50426  2.35726     1.54854       NaN       NaN          NaN
# 4 1948-04-01    1.65066  2.58785     1.67265       NaN       NaN          NaN
#
#      UNRATE  Year  Quarter
# 0       NaN  1947        2
# 1       NaN  1947        3
# 2       NaN  1947        4
# 3  3.733333  1948        1
# 4  3.666667  1948        2

# %%
def combine(df,left_on_col = ["YEAR FORECAST MADE","QUARTER"]):
    returnFrame = df
    for filename in os.listdir("../data/RawData/BLS"):
        to_merge = formatData(filename).reset_index(level=[0,1])
        to_merge.rename(columns={"Value":filename.split("_")[0]},inplace=True)
        returnFrame= returnFrame.merge(to_merge,how="left",left_on=left_on_col,right_on=["Year","Quarter"],suffixes=('', '_drop')).fillna(method="ffill")
    returnFrame.drop([col for col in training.columns if 'drop' in col], axis=1, inplace=True)
    return returnFrame.drop(columns = ["Year","Quarter"])

# %%
combine(quarterFred,["Year","Quarter"]).to_csv("../data/CleanData/QuarterlyFredWithItems.csv",index=False)

# %%
training
# Out:
#        YEAR FORECAST MADE  QUARTER  YEAR BEING FORECAST     INDICATOR  \
# 0                    1968        4                 1968    NominalGNP
# 1                    1968        4                 1968    NominalGNP
# 2                    1968        4                 1968    NominalGNP
# 3                    1968        4                 1968    NominalGNP
# 4                    1968        4                 1968    NominalGNP
# ...                   ...      ...                  ...           ...
# 36057                2021        2                 2024  Unemployment
# 36058                2021        2                 2024  Unemployment
# 36059                2021        2                 2024  Unemployment
# 36060                2021        2                 2024  Unemployment
# 36061                2021        2                 2024  Unemployment
#
#        FORECASTER ID  INDUSTRY Year.ID.ForecastYear.Quarter  \
# 0                  1       NaN                1968-1-1968-4
# 1                  2       NaN                1968-2-1968-4
# 2                  3       NaN                1968-3-1968-4
# 3                  4       NaN                1968-4-1968-4
# 4                  5       NaN                1968-5-1968-4
# ...              ...       ...                          ...
# 36057            586       2.0              2024-586-2021-2
# 36058            587       2.0              2024-587-2021-2
# 36059            588       1.0              2024-588-2021-2
# 36060            589       2.0              2024-589-2021-2
# 36061            590       1.0              2024-590-2021-2
#
#       Indicator.Year.ID.ForecastYear.Quarter  BIN 1  BIN 2  ...  ACTUAL_CONF  \
# 0                   NominalGNP-1968-1-1968-4    0.0    0.0  ...         0.00
# 1                   NominalGNP-1968-2-1968-4    0.0    0.0  ...         0.00
# 2                   NominalGNP-1968-3-1968-4    0.0    0.0  ...         0.00
# 3                   NominalGNP-1968-4-1968-4    0.0    0.0  ...         0.00
# 4                   NominalGNP-1968-5-1968-4    3.0    4.0  ...         0.04
# ...                                      ...    ...    ...  ...          ...
# 36057           Unemployment-2024-586-2021-2    0.0    0.0  ...         0.00
# 36058           Unemployment-2024-587-2021-2    0.0    0.0  ...         0.00
# 36059           Unemployment-2024-588-2021-2    0.0    0.0  ...         0.00
# 36060           Unemployment-2024-589-2021-2    0.0    0.0  ...         0.00
# 36061           Unemployment-2024-590-2021-2    0.0    0.0  ...         0.00
#
#        HIT  pred_average  pred_var  chicken  coffee    eggs  electricity  \
# 0      0.0         6.000  0.450000      NaN     NaN     NaN          NaN
# 1      0.0         6.100  1.040000      NaN     NaN     NaN          NaN
# 2      0.0         6.800  0.410000      NaN     NaN     NaN          NaN
# 3      0.0         6.150  1.327500      NaN     NaN     NaN          NaN
# 4      0.0         4.650  7.227500      NaN     NaN     NaN          NaN
# ...    ...           ...       ...      ...     ...     ...          ...
# 36057  0.0         5.514  0.578179   1.5005   4.659  1.6225       0.1395
# 36058  0.0         5.125  0.203125   1.5005   4.659  1.6225       0.1395
# 36059  0.0         5.125  0.203125   1.5005   4.659  1.6225       0.1395
# 36060  0.0         5.175  0.050625   1.5005   4.659  1.6225       0.1395
# 36061  0.0         5.175  0.050625   1.5005   4.659  1.6225       0.1395
#
#         rice  unleadedGasoline
# 0        NaN               NaN
# 1        NaN               NaN
# 2        NaN               NaN
# 3        NaN               NaN
# 4        NaN               NaN
# ...      ...               ...
# 36057  0.793            2.9055
# 36058  0.793            2.9055
# 36059  0.793            2.9055
# 36060  0.793            2.9055
# 36061  0.793            2.9055
#
# [36062 rows x 70 columns]

# %%
training.to_csv("../data/TrainingData/trainingWithItems.csv")
